# %%
# Mounting Google Drive to the notebook

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#### LIBRARIES

# Utils

import time
import os
import glob
import numpy as np
from numpy import array
import random
import math
import cv2

# Visualization

import matplotlib.pyplot as plt

# %%
# First, upload .py files with files>upload (menu to the left)
# Lib functions as modules

import feature1_images_for_training as f1
import feature2_train_test_set as f2
import model_CNN
import train_function
import psnr
import test_transform
import SR_test

# %%
# Keras 

from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.layers.core import Activation
from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.python.keras.layers.convolutional import UpSampling2D
from tensorflow.python.keras.layers.core import Flatten
from tensorflow.python.keras.layers import Input
from tensorflow.python.keras.layers.convolutional import Conv2D, Conv2DTranspose
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.layers.advanced_activations import LeakyReLU, PReLU
from tensorflow.python.keras.layers import add
from tensorflow.python.keras.optimizers import Adam

# %%
#### STEP 0: DIRECTORIES SPECIFIED

random.seed(2019)
#os.getcwd()
path = "/content/drive/My Drive/SR_images"
os.chdir(path)

# %%
# !ls
# Out:
# HR  model_e50_s400.h5  Test_HR	weights_model_e50_s400.h5
# LR  model.h5	       Test_LR	weights_model.h5

# %%
#### STEP 1: FEATURES AND IMAGE TRANSFORMATIONS 

hr_paths = f1.get_paths("HR")
len(hr_paths)
# Out:
# 1470

# %%
hr_paths_sample = np.random.choice(hr_paths, size=450, replace=False)
len(hr_paths_sample)
# Out:
# 450

# %%
start_1 = time.time()

HR_cropped =f1.cropped_imgs(hr_paths_sample)
len(HR_cropped)

end_1 = time.time()

# %%
#### STEP 2: TRAIN AND TEST SPLIT 

start_2 = time.time()

x_train_lr, x_train_hr, x_test_lr, x_test_hr =f2.train_test_data(HR_cropped, number_of_images = len(HR_cropped))

end_2 = time.time()

# %%
del HR_cropped
import gc
gc.collect()
# Out:
# 0

# %%
x_train_lr = f2.ndarray_to_4dim(x_train_lr, image_size = 16)
x_train_hr = f2.ndarray_to_4dim(x_train_hr, image_size = 32)
x_test_lr = f2.ndarray_to_4dim(x_test_lr, image_size = 16)
x_test_hr = f2.ndarray_to_4dim(x_test_hr, image_size = 32)

# %%
#### STEP 3: TRAIN MODEL

start_3 = time.time()

epochs = 55
batch_size = 150

generator, generated_train, loss, val_loss = train_function.train(x_train_lr = x_train_lr, x_train_hr = x_train_hr, epochs = epochs, batch_size = batch_size)

end_3 = time.time()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16, 16, 3)    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 64)   15616       input_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu (PReLU)                 (None, 16, 16, 64)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   36928       p_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 16, 16, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   36928       p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_1 (Batch (None, 16, 16, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_v1_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_2 (Batch (None, 16, 16, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   36928       p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_3 (Batch (None, 16, 16, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_v1_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_4 (Batch (None, 16, 16, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   36928       p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_5 (Batch (None, 16, 16, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_v1_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_6 (Batch (None, 16, 16, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_7 (Batch (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_v1_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_8 (Batch (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_9 (Batch (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_10 (Batc (None, 16, 16, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_11 (Batc (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_12 (Batc (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_13 (Batc (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_14 (Batc (None, 16, 16, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_15 (Batc (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_16 (Batc (None, 16, 16, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 16, 16, 64)   64          batch_normalization_v1_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_17 (Batc (None, 16, 16, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_18 (Batc (None, 16, 16, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_19 (Batc (None, 16, 16, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_20 (Batc (None, 16, 16, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_21 (Batc (None, 16, 16, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_22 (Batc (None, 16, 16, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_23 (Batc (None, 16, 16, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_24 (Batc (None, 16, 16, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_25 (Batc (None, 16, 16, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_26 (Batc (None, 16, 16, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_27 (Batc (None, 16, 16, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_28 (Batc (None, 16, 16, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_29 (Batc (None, 16, 16, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_30 (Batc (None, 16, 16, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 16, 16, 64)   64          batch_normalization_v1_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 64)   36928       p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_31 (Batc (None, 16, 16, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_v1_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_32 (Batc (None, 16, 16, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 64)   0           p_re_lu[0][0]
#                                                                  batch_normalization_v1_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 256)  147712      add[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 32, 32, 256)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 3)    62211       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 3)    0           conv2d_35[0][0]
# ==================================================================================================
# Total params: 1,453,699
# Trainable params: 1,449,475
# Non-trainable params: 4,224
# __________________________________________________________________________________________________
# Train on 159112 samples, validate on 39778 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/55
# 159112/159112 [==============================] - 506s 3ms/sample - loss: 0.0093 - val_loss: 0.0039
# Epoch 2/55
# 159112/159112 [==============================] - 491s 3ms/sample - loss: 0.0031 - val_loss: 0.0027
# Epoch 3/55
# 159112/159112 [==============================] - 491s 3ms/sample - loss: 0.0024 - val_loss: 0.0023
# Epoch 4/55
# 159112/159112 [==============================] - 490s 3ms/sample - loss: 0.0022 - val_loss: 0.0025
# Epoch 5/55
# 159112/159112 [==============================] - 489s 3ms/sample - loss: 0.0020 - val_loss: 0.0020
# Epoch 6/55
# 159112/159112 [==============================] - 489s 3ms/sample - loss: 0.0019 - val_loss: 0.0021
# Epoch 7/55
# 159112/159112 [==============================] - 489s 3ms/sample - loss: 0.0018 - val_loss: 0.0019
# Epoch 8/55
# 159112/159112 [==============================] - 489s 3ms/sample - loss: 0.0017 - val_loss: 0.0018
# Epoch 9/55
# 159112/159112 [==============================] - 489s 3ms/sample - loss: 0.0016 - val_loss: 0.0018
# Epoch 10/55
# 159112/159112 [==============================] - 498s 3ms/sample - loss: 0.0017 - val_loss: 0.0018
# Epoch 11/55
# 159112/159112 [==============================] - 498s 3ms/sample - loss: 0.0016 - val_loss: 0.0017
# Epoch 12/55
# 159112/159112 [==============================] - 497s 3ms/sample - loss: 0.0015 - val_loss: 0.0017
# Epoch 13/55
# 159112/159112 [==============================] - 497s 3ms/sample - loss: 0.0015 - val_loss: 0.0017
# Epoch 14/55
# 159112/159112 [==============================] - 497s 3ms/sample - loss: 0.0015 - val_loss: 0.0016
# Epoch 15/55
# 159112/159112 [==============================] - 496s 3ms/sample - loss: 0.0015 - val_loss: 0.0016
# Epoch 16/55
# 159112/159112 [==============================] - 497s 3ms/sample - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/55
# 159112/159112 [==============================] - 499s 3ms/sample - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0014 - val_loss: 0.0015
# Epoch 20/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0014 - val_loss: 0.0015
# Epoch 21/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 22/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 23/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0015 - val_loss: 0.0015
# Epoch 24/55
# 159112/159112 [==============================] - 504s 3ms/sample - loss: 0.0014 - val_loss: 0.0015
# Epoch 25/55
# 159112/159112 [==============================] - 503s 3ms/sample - loss: 0.0014 - val_loss: 0.0015
# Epoch 26/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 27/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 28/55
# 159112/159112 [==============================] - 498s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 29/55
# 159112/159112 [==============================] - 496s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 30/55
# 159112/159112 [==============================] - 496s 3ms/sample - loss: 0.0015 - val_loss: 0.0015
# Epoch 31/55
# 159112/159112 [==============================] - 498s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 32/55
# 159112/159112 [==============================] - 499s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 33/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 34/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 35/55
# 159112/159112 [==============================] - 501s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 36/55
# 159112/159112 [==============================] - 500s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 37/55
# 159112/159112 [==============================] - 496s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 38/55
# 159112/159112 [==============================] - 495s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 39/55
# 159112/159112 [==============================] - 497s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 40/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 41/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 42/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0013 - val_loss: 0.0017
# Epoch 43/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 44/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 45/55
# 159112/159112 [==============================] - 503s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 46/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0012 - val_loss: 0.0015
# Epoch 47/55
# 159112/159112 [==============================] - 503s 3ms/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 48/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 49/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 50/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 51/55
# 159112/159112 [==============================] - 502s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 52/55
# 159112/159112 [==============================] - 500s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 53/55
# 159112/159112 [==============================] - 499s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 54/55
# 159112/159112 [==============================] - 500s 3ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 55/55
# 159112/159112 [==============================] - 499s 3ms/sample - loss: 0.0012 - val_loss: 0.0014

# %%
#### STEP 4: TEST AND PLOT

test_im = generator.evaluate(x_test_lr, x_test_hr)
# Out:
# 22099/22099 [==============================] - 24s 1ms/sample - loss: 0.0016

# %%
epoch = range(epochs)
plt.figure()
plt.plot(epoch, loss, 'bo', label='Training loss')
plt.plot(epoch, val_loss, 'ro', label='Validation loss')
plt.plot(test_im, 'go', label='Test loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#Predict snippets based on model download
image_shape = (16,16,3)
generator = model_CNN.Generator(image_shape).generator()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
generator.load_weights('model.h5')

# %%
#Predict snippets
gen_imgs = generator.predict(x_test_lr)
len(gen_imgs)
# Out:
# 22099

# %%
index = 21221
result = gen_imgs[index]
test_hr = x_test_hr[index]
test_lr = x_test_lr[index]

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 16), sharey=False)
axs[0].imshow(result, interpolation='nearest')
axs[1].imshow(test_hr, interpolation='nearest')
axs[2].imshow(test_lr, interpolation='nearest')
axs[0].set_title("Model Output")
axs[1].set_title("Ground Truth")
axs[2].set_title("Model Input")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
psnr_list = []
for i in range(len(gen_imgs)):
    psnr_item = psnr.psnr(gen_imgs[i], x_test_hr[i])
    psnr_list.append(psnr_item)

# %%
plt.figure()
plt.plot(psnr_list, 'bo', label='Test(PSNR)')
plt.title('Test(PSNR)')
plt.legend()
plt.show()

# %%
#it is good! 5 epochs = 26.6 50 epochs = 32.6 -; 33.66 55 epochs on 150 batch
mean_psnr = np.mean(psnr_list)
mean_psnr
# Out:
# 33.66002523009204

# %%
#### STEP 5: TEST - HOLDOUT DATA (whole images)

# %%
path = "/content/drive/My Drive/SR_images"
os.chdir(path)

# %%
input_pic = f1.get_paths("Test_LR")
truth = f1.get_paths("Test_HR")

# %%
input_pic.sort()
truth.sort()

# %%
#test
psnr_sco = SR_test.super_resolution(input_pic[0], truth[0], generator)[0]
psnr_sco
# Out:
# 29.552601970754985

# %%
start_4 = time.time()

whole_psnr = []
for i in range(len(input_pic)):
  psnr_score = SR_test.super_resolution(input_pic[i], truth[i], generator)[0]
  whole_psnr.append(psnr_score)
  
end_4 = time.time()

# %%
plt.figure()
plt.plot(whole_psnr, 'bo', label='Test_whole(PSNR)')
plt.title('Test_whole(PSNR)')
plt.legend()
plt.show()

# %%
#it is ok 26.6 on 55/150 model
mean_psnr_test = np.mean(whole_psnr)
mean_psnr_test
# Out:
# 26.602699895252393

# %%
lr_list = []
hr_list = []
result_list = []
for i in range(len(input_pic)):
  lr = SR_test.super_resolution(input_pic[i], truth[i], generator)[1]
  hr = SR_test.super_resolution(input_pic[i], truth[i], generator)[2]
  result = SR_test.super_resolution(input_pic[i], truth[i], generator)[3]
  lr_list.append(lr)
  hr_list.append(hr)
  result_list.append(result)

# %%
index = 22
result = result_list[index]
test_hr = hr_list[index]
test_lr = lr_list[index]

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 16), sharey=False)
axs[0].imshow(result, interpolation='nearest')
axs[1].imshow(test_hr, interpolation='nearest')
axs[2].imshow(test_lr, interpolation='nearest')
axs[0].set_title("Model Output")
axs[1].set_title("Ground Truth")
axs[2].set_title("Model Input")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#### SUMMARISE RUNNING TIME
IMAGE_time = end_1 - start_1
SPLIT_time = end_2 - start_2
TRAIN_time = end_3 - start_3
TEST_time = end_4 - start_4

print("IMAGE TRANSFORMATION TIME: ", IMAGE_time)
print("TRAIN-TEST SPLIT AND DOWNSAMPLING TIME: ", SPLIT_time)
print("TRAINING TIME: ", TRAIN_time)
print("TEST_SET TIME: ", TEST_time)
# Out:
# IMAGE TRANSFORMATION TIME:  136.81325483322144
# TRAIN-TEST SPLIT AND DOWNSAMPLING TIME:  2.5861096382141113
# TRAINING TIME:  27449.50022292137
# TEST_SET TIME:  7.575206279754639
